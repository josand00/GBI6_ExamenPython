# %% [markdown]
# <img src="https://www.ikiam.edu.ec/img/logo-ikiam-grey.png" width=300 height=240 />
#
# # <center><h2> EXAMEN PARCIAL PYTHON</h2></center>
#
#
# ## GBI6-2021II: BIOINFORMÁTICA
#
# **Camacho Aguilar, Angiely Valeria**
# - **21 años**
# - **Machala**
# - **Biotecnología**
# - **05-08-2022**
#
# Escriba una **tabla** con las características de su computador
# <table>
#   <tr>
#     <th>Nombre del dispositivo</th>
#     <th>Componentes</th>
#     <th>Especificaciones</th>
#   </tr>
#   <tr>
#     <td>Angiely-C</td>
#     <td>Procesador</td>
#     <td>Intel(R) Core(TM) i3-7020U CPU @ 2.30GHz</td>
#   </tr>
#   <tr>
#     <td></td>
#     <td>Ram</td>
#     <td>4,00 GB</td>
#   </tr>
#     <tr>
#     <td></td>
#     <td>Tipo de sistema</td>
#     <td>Sistema operativo de 64 bits</td>
#   </tr>
#    <tr>
#     <td></td>
#     <td>Windows</td>
#     <td>Windows 10 Pro</td>
#  </tr>
# </table>

# %% [markdown]
# <font color='red'>Color de texto</font>

# %% [markdown]
# ### REQUERIMIENTOS PARA EL EXAMEN
#
# Utilice de preferencia ```Jupyter``` de Anaconda, dado que tienen que hacer un control de cambios en cada pregunta.
#
# Para este examen se requiere dos documentos:
#
# 1. Archivo ```miningscience.py``` donde tendrá dos funciones:
#
# 2. Archivo ```2022I_GBI6_ExamenPython``` donde se llamará las funciones y se obtendrá resultados.

# %% [markdown]
# ## Ejercicio 0 [0.5 puntos]
# Realice cambios al cuaderno de jupyter:
# - Agregue el logo de la Universidad
# - Coloque sus datos personales
# - Escriba una **tabla** con las características de su computador

# %% [markdown]
# ## Ejercicio 1 [2 puntos]
# Cree el archivo ```miningscience.py``` con las siguientes dos funciones:
#
# i. ```download_pubmed```: para descargar la data de PubMed utilizando el **ENTREZ** de Biopython. El parámetro de entrada para la función es el ```keyword```.
#
# ii. ```science_plots```: la función debe
#
# - utilizar como argumento de entrada la data descargada por ```download_pubmed```
# - ordenar los conteos de autores por país en orden ascedente y
# - seleccionar los cinco más abundantes. Con esta selección debe graficar un ```pie_plot```. Como guía para el conteo por países puede usar el ejemplo de [MapOfScience](https://github.com/CSB-book/CSB/blob/master/regex/solutions/MapOfScience_solution.ipynb).
#
# iii *Cree un docstring para cada función.*
#
# Luego de crear las funciones, cargue el módulo ```miningscience``` como ```msc``` e **imprima docstring de cada función**.

# %%
# Escriba aquí su código para el ejercicio 1

import miningscience

# %%
import miningscience as msc

# %%
help (msc.download_pubmed)
help (msc.science_plots)
# Out:
# Help on function download_pubmed in module miningscience:
#
# download_pubmed(keyword)
#     Este script permite buscar articulos en pubmed por medio de  palabras claves
#
# Help on function science_plots in module miningscience:
#
# science_plots(file)
#     Codigo para seleccionar los paises de mayor a menor incidencia

# %% [markdown]
# ## Ejercicio 2 [2 puntos]
#
#
# Utilice dos veces la función ```download_pubmed``` para:
#
# - Descargar la data, utilizando los keyword de su preferencia.
# - Guardar el archivo descargado en la carpeta ```data```.
#
# Para cada corrida, imprima lo siguiente:
#
# ```python
# 'El número artículos para KEYWORD es: XX' # Que se cargue con inserción de texto o valor que correspondea KEYWORD y XX
# ```

# %%
import os
import re

# %%
# Escriba aquí su código para el ejercicio 2
# es escribible , write...

a = msc.download_pubmed("cats")
b = len (a)
print ('El número artículos para cats es: ',b)
with open ("Data/cats.txt","w") as txt:
    txt.write(a)
# Out:
# El número artículos para cats es:  2147910

# %%
v = msc.download_pubmed("dogs")
c = len (v)
print ('El número artículos para dogs es: ',c)
with open ("Data/dogs.txt","w") as txt:
    txt.write(v)
# Out:
# El número artículos para dogs es:  2098497

# %% [markdown]
# ## Ejercicio 3 [1.5 puntos]
#
# Utilice dos veces la función ```science_plots``` para:
#
# - Visualizar un pie_plot para cada data descargada en el ejercicio 2.
# - Guardar los pie_plot en la carpeta ```img```

# %%
# Escriba aquí su código para el ejercicio 3
import matplotlib.pyplot as plt
cats = msc.science_plots (a)
with open ("img/gatos.png","w") as png:
    cats

# %%
# Escriba aquí su código para el ejercicio 3
dogs = msc.science_plots (v)

plt.savefig('img/perros.png', dpi=500)
plt.show()

# %% [markdown]
# ## Ejercicio 4 [1 punto]
#
# **Interprete** los resultados de las figuras del **ejercicio 3**
#
# Se puede observar en el diagrama de pastel de la palabra cats que los 5 países con más publicaciones respecto a gatos esta en primer lugar es China 25.1%, le sigue Brazil 21.4%, luego Italy 20.0%, Japan 18.5%, y por ultimo Alemania con 14.9%, y respecto a la palabra dogs, el primero de lo 5 paises con mas publicaciones con esa palabra es Japan con 29,9%, luego Italy con 20.7%, China con 18.8%, Brazil con 16,2 y por ultimo Alemania con 14,3%

# %% [markdown]
# *Escriba la respuesta del ejercicio 5*
#
# . Se realizo un arbol filogenetico con los accesion list
#
#
# .
#
# .

# %% [markdown]
# ## Ejercicio 5 [2 puntos]
#
# Para algún **gen de las enzimas que intervienen en la ruta metabolica de la gluconeogenesis** ([Lista de genes por tipología](https://www.genome.jp/pathway/map00010+C00068)), realice lo siguiente:
#
# 1. Una búsqueda en la página del [NCBI nucleotide](https://www.ncbi.nlm.nih.gov/nucleotide/).
#
# 2. Descargue el ```Accession List``` de su búsqueda y guarde en la carpeta ```data```.
#
# 3. Cargue el ```Accession List``` en este notebook y haga una descarga de las secuencias de los **quince primeros** IDs de la accesión.
#
# 4. Arme un árbol filogenético para los resultados del paso 3.
#
# 5. Guarde su arbol filogénetico en la carpeta ```img```
#
# 5. Interprete el árbol del paso 4.

# %%
from Bio import Entrez
from Bio import Phylo
from Bio import AlignIO
from Bio import SeqIO
from Bio.Phylo.TreeConstruction import DistanceCalculator
from Bio.Phylo.TreeConstruction import DistanceTreeConstructor
from Bio.Align.Applications import ClustalwCommandline
import matplotlib.pyplot as plt
import os

with open('Data/sequence.seq') as file:
    text = file.read()
text = text.split('\n')
text = ','.join(text[:10])

handle = Entrez.efetch( db="nucleotide", rettype="gb", retmode="text", id = text)
print(handle.url)
records = SeqIO.parse("Data/sequence.gb", "genbank") 
count = SeqIO.write(records, "Data/sequence.fasta", "fasta") 

clustalw_exe = r"C:\Program Files (x86)\ClustalW2\clustalw2.exe"
clustalw_cline = ClustalwCommandline(clustalw_exe, infile = "Data/sequence.fasta")
assert os.path.isfile(clustalw_exe), "Clustal_W executable is missing or not found"
stdout, stderr = clustalw_cline()
print(clustalw_cline)

ClustalAlign = AlignIO.read("Data/sequence.aln", "clustal")

with open("Data/sequence.aln","r") as aln: 
    alignment = AlignIO.read(aln,"clustal")
    
calculator = DistanceCalculator('identity')
distance_matrix = calculator.get_distance(alignment)
constructor = DistanceTreeConstructor(calculator)
tree = constructor.build_tree(alignment)
tree.rooted = True
fig = plt.figure(figsize=(10, 12), dpi=200)  # crea figura & set the size 
matplotlib.rc('font', size=12)               # fontsize of the leaf and node labels 
matplotlib.rc('xtick', labelsize=20)         # fontsize of the tick labels
matplotlib.rc('ytick', labelsize=20)         # fontsize of the tick labels
axes = fig.add_subplot(1, 1, 1)
Phylo.draw(tree, axes=axes)
fig.savefig("img/arbol.jpg")
# Out:
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=nucleotide&rettype=gb&retmode=text&id=JAHUZN010000007.1%2CCM033490.1%2CLR792838.1%2CJACTAM010000024.1%2CCM040959.1%2CCP017717.1%2CCP006567.1%2CCP085193.1%2CCP041602.2%2CCP051010.1&tool=biopython&email=gualapuro.moises%40gmail.com
# "C:\Program Files (x86)\ClustalW2\clustalw2.exe" -infile=Data/sequence.fasta

# %% [markdown]
# **Escriba aquí la interpretación del árbol**
#
# Se puede observar en el grafico del árbol filogenético que la enzima 6-fosfo-beta-glucosidasa que interviene en la ruta metabolica de la gluconeogenesis, comparte semejanza con los identificadores de genes denominados: EU896727.1, EU896729.1, y EU896728.1, mientras que los identificadores de genes con los que mas distan de la enzima 6-fosfo-beta-glucosidasa son KM435261.1, KM435259.1, KM435258.1, KM435260.1

# %% [markdown]
# ## Ejercicio 6 [1 punto]
#
#
# 1. Cree en GitHub un repositorio de nombre ```GBI6_ExamenPython```.
# 2. Cree un archivo ```Readme.md``` que debe tener lo siguiente:
# - Datos personales
# - Características del computador
# - Versión de Python/Anaconda y de cada uno de los módulos/paquetes y utilizados
# - Explicación de la data utilizada
# - Un diagrama de procesos del módulo ```miningscience```
# 3. Asegurarse que su repositorio tiene las carpetas ```data``` e ```img``` con los archivos que ha ido guardando en las preguntas anteriores.
# 4. Realice al menos 1 control de la versión (commits) por cada ejercicio (del 1 al 5), con un mensaje que inicie como:
#
# ```sh
# Carlitos Alimaña ha realizado el ejercicio 1
# ```
# ```sh
# Carlitos Alimaña ha realizado el ejercicio 2
# ```
# ```sh
# ...
# ```
